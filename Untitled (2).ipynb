# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\prave\OneDrive\TOP TECH DEVELOPERS\TASK2\financials.csv")

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name   Year
# ...

# %%
df.iloc[0]
# Out:
# Segment                    Government
# Country                        Canada
#  Product                   Carretera
#  Discount Band                  None
#  Units Sold                $1,618.50
#  Manufacturing Price           $3.00
#  Sale Price                   $20.00
#  Gross Sales              $32,370.00
#  Discounts                      $-
#   Sales                   $32,370.00
#  COGS                     $16,185.00
#  Profit                   $16,185.00
# Date                       01/01/2014
# Month Number                        1
#  Month Name                  January
# Year                             2014
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Segment                    Government
# Country                        Canada
#  Product                   Carretera
#  Discount Band                  None
#  Units Sold                $1,618.50
#  Manufacturing Price           $3.00
#  Sale Price                   $20.00
#  Gross Sales              $32,370.00
#  Discounts                      $-
#   Sales                   $32,370.00
#  COGS                     $16,185.00
#  Profit                   $16,185.00
# Date                       01/01/2014
# Month Number                        1
#  Month Name                  January
# Year                             2014
# Name: 0, dtype: object

# %%
df['Segment']
# Out:
# 0            Government
# 1            Government
# 2             Midmarket
# 3             Midmarket
# 4             Midmarket
#              ...
# 695      Small Business
# 696      Small Business
# 697          Government
# 698          Government
# 699    Channel Partners
# Name: Segment, Length: 700, dtype: object

# %%
df['Year'] = df['Year'] + 1

# %%
df.drop('Year', axis=1, inplace=True)

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.sort_values('Month Number')
# Out:
#               Segment                   Country     Product   Discount Band   \
# 1          Government                   Germany   Carretera            None
# 497         Midmarket                    Canada        Velo            High
# 485        Enterprise  United States of America    Amarilla            High
# 467         Midmarket                   Germany        Velo            High
# 428  Channel Partners  United States of America         VTT          Medium
# ..                ...                       ...          ...             ...
# 611  Channel Partners                   Germany    Amarilla            High
# 121  Channel Partners                    France       Paseo             Low
# 122  Channel Partners                    Mexico       Paseo             Low
# 261    Small Business                   Germany        Velo          Medium
# 381        Government                    Mexico       Paseo          Medium
#
# ...

# %%
df.sort_index()
# Out:
#               Segment                   Country     Product   Discount Band   \
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# 5          Government                   Germany   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df['Segment'] = [Government,None,Midmarket]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df['Segment'] = [Government,None,Midmarket]
#
# NameError: name 'Government' is not defined

# %%
df.isnull()
# Out:
#      Segment  Country   Product    Discount Band    Units Sold   \
# 1      False    False      False            False         False
# 2      False    False      False            False         False
# 3      False    False      False            False         False
# 4      False    False      False            False         False
# 5      False    False      False            False         False
# ..       ...      ...        ...              ...           ...
# 695    False    False      False            False         False
# 696    False    False      False            False         False
# 697    False    False      False            False         False
# 698    False    False      False            False         False
# 699    False    False      False            False         False
#
#       Manufacturing Price    Sale Price    Gross Sales    Discounts   \
# 1                    False         False          False        False
# ...

# %%
df['Segment'].fillna(df['Segment'].mean(0), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df['Segment'].fillna(df['Segment'].mean(0), inplace=True)
#
# File C:\Apps\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\Apps\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# ...

# %%
df1 = pd.DataFrame({'ID':[1,2,3], 'Name':['A','B','C']})
df2 = pd.DataFrame({'ID':[1,2,3], 'Marks':[90,85,95]})

# %%
pd.merge(df1, df2, on='ID')
# Out:
#    ID Name  Marks
# 0   1    A     90
# 1   2    B     85
# 2   3    C     95

# %%
pd.concat([df1, df2], axis=0)
# Out:
#    ID Name  Marks
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   90.0
# 1   2  NaN   85.0
# 2   3  NaN   95.0

# %%
df.to_excel('output.xlsx', index=False)     
df.to_json('output.json', orient='records')
